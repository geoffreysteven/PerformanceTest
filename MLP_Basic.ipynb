# %%
# Credit for this code is due to Brown Lee and his oustanding books
# on Deep Learning and Machine Learning.
#

import keras
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd
import pickle
np.random.seed(42)
# Out:
# Using TensorFlow backend.

# %%
dataset=np.loadtxt("pima-indians-diabetes.csv", delimiter=",")

X = dataset[:,:8]
y = dataset[:,8]

print(X.shape)
print(y.shape)
# Out:
# (768, 8)
# (768,)

# %%
# my model

model=Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='tanh'))

# %%
model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

# %%
tbCallBack = keras.callbacks.TensorBoard(log_dir='/output', 
                                         histogram_freq=0, 
                                         write_graph=True, 
                                         write_images=True)

# %%
# %time model.fit(X,y, epochs=150, batch_size=10, verbose=1, callbacks=[tbCallBack])
# Out:
# Epoch 1/150
# 768/768 [==============================] - 2s - loss: 5.4038 - acc: 0.6055
# Epoch 2/150
# 768/768 [==============================] - 0s - loss: 5.3781 - acc: 0.6484
# Epoch 3/150
# 768/768 [==============================] - 0s - loss: 5.3464 - acc: 0.6576
# Epoch 4/150
# 768/768 [==============================] - 0s - loss: 5.3504 - acc: 0.6589
# Epoch 5/150
# 768/768 [==============================] - 0s - loss: 5.3622 - acc: 0.6602
# Epoch 6/150
# 768/768 [==============================] - 0s - loss: 5.3625 - acc: 0.6615
# Epoch 7/150
# 768/768 [==============================] - 0s - loss: 5.3834 - acc: 0.6602
# Epoch 8/150
# 768/768 [==============================] - 0s - loss: 5.3706 - acc: 0.6576
# Epoch 9/150
# 768/768 [==============================] - 0s - loss: 5.3646 - acc: 0.6602
# Epoch 10/150
# 768/768 [==============================] - 0s - loss: 5.4301 - acc: 0.6484
# Epoch 11/150
# ...

# %%
scores = model.evaluate(X,y)
# Out:
#  32/768 [>.............................] - ETA: 0s

# %%
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# acc: 71.35%
